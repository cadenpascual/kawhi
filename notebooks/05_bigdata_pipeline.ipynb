# %%
import pandas as pd
import numpy as np

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent  
sys.path.append(str(ROOT))

from src.pipelines.defense_parquet import run_season_pipeline
# Out:
# Loading spatial maps...
# Loading shots from: ../data/processed/shots/all_season_shots.parquet

# %%
run_season_pipeline()
# Out:
# Found 635 files to process in ../data/raw/7z/
# Running on 7 parallel workers...
# Loading spatial maps...
# Loading spatial maps...
# Loading spatial maps...
# Loading spatial maps...
# Loading spatial maps...
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading spatial maps...
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading spatial maps...
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Pipeline Diagnostics: {'no_event': 12, 'no_release': 15, 'feat_error': 0, 'exception': 0, 'processed': 150}
# [1/635] Success: traj_01.09.2016.CHI.at.ATL_21500551.parquet (150 shots)
# ...

# %%
defense_df = pd.read_parquet("../data/processed/traj_features/traj_01.18.2016.GSW.at.CLE_21500622.parquet")
defense_df2 = pd.read_parquet("../data/processed/traj_features/defense_01.18.2016.GSW.at.CLE_21500622.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 defense_df = pd.read_parquet("../data/processed/traj_features/traj_01.18.2016.GSW.at.CLE_21500622.parquet")
# ----> 2 defense_df2 = pd.read_parquet("../data/processed/traj_features/defense_01.18.2016.GSW.at.CLE_21500622.parquet")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
# ...

# %%
defense_df.columns
# Out:
# Index(['GAME_ID', 'SHOT_EVENT_ID', 'tracking_event_id', 'event_list_idx',
#        'PERIOD', 'game_clock', 'PLAYER_ID', 'TEAM_ID', 'flipped_coordinates',
#        'ball_x_traj', 'ball_y_traj', 'off1_pid', 'off1_x_traj', 'off1_y_traj',
#        'off1_q_traj', 'def1_pid', 'def1_x_traj', 'def1_y_traj', 'off2_pid',
#        'off2_x_traj', 'off2_y_traj', 'off2_q_traj', 'def2_pid', 'def2_x_traj',
#        'def2_y_traj', 'off3_pid', 'off3_x_traj', 'off3_y_traj', 'off3_q_traj',
#        'def3_pid', 'def3_x_traj', 'def3_y_traj', 'off4_pid', 'off4_x_traj',
#        'off4_y_traj', 'off4_q_traj', 'def4_pid', 'def4_x_traj', 'def4_y_traj',
#        'off5_pid', 'off5_x_traj', 'off5_y_traj', 'off5_q_traj', 'def5_pid',
#        'def5_x_traj', 'def5_y_traj', 'release_frame_global_idx',
#        'pbp_frame_global_idx', 'local_release_idx', 'local_pbp_idx',
#        'ball_z_traj', 'SHOT_MADE_FLAG'],
#       dtype='object')

# %%
defense_df2.columns
# Out:
# Index(['GAME_ID', 'SHOT_EVENT_ID', 'tracking_event_id', 'event_list_idx',
#        'PERIOD', 'game_clock', 'PLAYER_ID', 'TEAM_ID', 'flipped_coordinates',
#        'ball_x_traj', 'ball_y_traj', 'off1_pid', 'off1_x_traj', 'off1_y_traj',
#        'off1_q_traj', 'def1_pid', 'def1_x_traj', 'def1_y_traj', 'off2_pid',
#        'off2_x_traj', 'off2_y_traj', 'off2_q_traj', 'def2_pid', 'def2_x_traj',
#        'def2_y_traj', 'off3_pid', 'off3_x_traj', 'off3_y_traj', 'off3_q_traj',
#        'def3_pid', 'def3_x_traj', 'def3_y_traj', 'off4_pid', 'off4_x_traj',
#        'off4_y_traj', 'off4_q_traj', 'def4_pid', 'def4_x_traj', 'def4_y_traj',
#        'off5_pid', 'off5_x_traj', 'off5_y_traj', 'off5_q_traj', 'def5_pid',
#        'def5_x_traj', 'def5_y_traj', 'release_frame_global_idx',
#        'pbp_frame_global_idx', 'local_release_idx', 'local_pbp_idx',
#        'ball_z_traj', 'SHOT_MADE_FLAG'],
#       dtype='object')
