# %%
import pandas as pd
import numpy as np

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent  
sys.path.append(str(ROOT))

from src.pipelines.defensive_features import run_season_pipeline

# %%
run_season_pipeline()
# Out:
# Loading shots from: ../data/processed/shots/all_season_shots.parquet
# Found 1 files to process in ../data/raw/7z_test/
# Error on shot 82451: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# [1/1] Success: defense_01.01.2016.CHA.at.TOR_21500492.parquet (154 shots)
#
# Pipeline Complete.

# %%
defense_df = pd.read_parquet("../data/processed/def_features/defense_01.01.2016.CHA.at.TOR_21500492.parquet")

# %%
defense_df.head()
# Out:
#     GAME_ID  SHOT_EVENT_ID tracking_event_id  release_frame_idx  \
# 0  21500492              2                 4                306
# 1  21500492              4                 4                456
# 2  21500492              5                 5                131
# 3  21500492              6                 2               1149
# 4  21500492              9                 7                382
#
#    event_list_idx  PERIOD  game_clock  PLAYER_ID     TEAM_ID       x_ft  ...  \
# 0               3       1         701       2449  1610612761   3.750000  ...
# 1               3       1         695     202685  1610612761   0.000000  ...
# 2               4       1         685     203469  1610612766  -0.333333  ...
# 3               1       1         666     200768  1610612761  -1.000000  ...
# 4               6       1         659     201587  1610612766 -13.000000  ...
#
#    w1_close_def_dist_min  w1_shooter_speed_mean  w1_shooter_speed_max  \
# 0               0.073086               5.250848             12.025695
# 1               0.436427              11.883404             17.000811
# 2               0.951215               3.774481              9.099534
# 3               2.691214               6.773811             12.582278
# 4               3.123662              11.838538             15.703859
#
#    w1_def_speed_mean  w1_closing_speed_mean  shooter_speed  \
# 0           7.889424              -0.987745       1.659919
# 1           5.686209               7.156711       2.928585
# 2           9.508523              -2.512791       3.092958
# 3           7.687874              -0.340310       7.131827
# 4           7.419729              -1.823160       8.890109
#
#    game_clock_tracking  shot_clock_tracking  w0_shooter_accel_mean  \
# 0               701.02                24.00               4.760262
# 1               695.03                20.14               9.464224
# 2               685.03                24.00               9.931348
# 3               667.31                 9.72              12.913065
# 4               659.00                24.00              15.761570
#
#    w1_shooter_accel_mean
# 0              14.613158
# 1              12.239021
# 2               7.748689
# 3              16.376734
# 4              12.040655
#
# [5 rows x 35 columns]
